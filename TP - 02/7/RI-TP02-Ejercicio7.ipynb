# %%
import sys
sys.path.insert(0, '../1/')

# %%
import tokenizer_uno

t = tokenizer_uno.Tokenizer(dir='pg2000.txt')
t.discovery_dir()
terms = t.get_terms()

# %%
xterms = {t[0]: t[1]['all'] for t in terms.items()}
# Out:
# {'que': 21476,
#  'los': 4748,
#  'con': 4201,
#  'por': 3940,
#  'las': 3468,
#  'don': 2652,
#  'del': 2622,
#  'como': 2539,
#  'mas': 2270,
#  'quijote': 2132,
#  'sancho': 2090,
#  'para': 1463,
#  'porque': 1400,
#  'dijo': 1350,
#  'una': 1339,
#  'tan': 1243,
#  'todo': 1178,
#  'sin': 1156,
#  'esta': 1154,
#  'ser': 1056,
#  'senor': 1053,
#  'asi': 1053,
#  'sus': 1049,
#  'bien': 1047,
#  'habia': 1032,
#  'pero': 1014,
#  'respondio': 1005,
#  'merced': 896,
#  'quien': 888,
#  'esto': 882,
#  'pues': 865,
#  'vuestra': 851,
#  'todos': 815,
#  'este': 814,
#  'cuando': 777,
#  'era': 754,
#  'cual': 749,
#  'donde': 736,
#  'sino': 693,
#  'dos': 681,
#  'caballero': 658,
#  'fue': 644,
#  'ella': 602,
#  'decir': 549,
#  'muy': 535,
#  'hacer': 534,
#  'aquel': 534,
#  'aunque': 531,
#  'dios': 529,
#  'aqui': 516,
#  'otra': 515,
#  'senora': 511,
#  'otro': 505,
#  'son': 481,
#  'estaba': 478,
#  'hay': 471,
#  'mal': 458,
#  'dijo:': 457,
#  'sobre': 454,
# ...

# %% [markdown]
# ### Resultados
#
# A continuacion graficamos la distribucion de los terminos

# %%
import numpy as np
from matplotlib import pyplot as plt

# pl=[1/i for i in range(1, len(terms.keys())+1)]

xterms = {t[0]: t[1]['all'] for t in terms.items()} 

#names = ['id','freq']
#formats = ['str','f8']
#dtype = dict(names = names, formats=formats)
#array = np.array(list(xterms.items()), dtype=dtype)

exp = [ 1/i for i in range(1, len(xterms)+1)]

fig, ax = plt.subplots()  # Create a figure and an axes.
ax.plot(list(xterms), exp, label='Power law \(Expected\)')  # Plot some data on the axes.
ax.plot(list(xterms), list(xterms.values()), label='Result')  # ... and some more.
ax.set_xlabel('x label')  # Add an x-label to the axes.
ax.set_ylabel('y label')  # Add a y-label to the axes.
ax.set_title("Simple Plot")  # Add a title to the axes.
ax.legend()
fig.show()
# Out:
# /Users/mr.grassho/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:22: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
# Error in callback <function flush_figures at 0x11e60aa70> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/miniconda3/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py in flush_figures()
#     119         # ignore the tracking, just draw and close all figures
#     120         try:
# --> 121             return show(True)
#     122         except Exception as e:
#     123             # safely show traceback if in IPython, else raise
#
# ~/miniconda3/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      41             display(
#      42                 figure_manager.canvas.figure,
# ...
