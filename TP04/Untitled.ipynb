# %%
import matplotlib.pyplot as plt
import numpy as np

def gaussian(x, mu, sig):
    return x + mu*x

x_values = np.linspace(0, 1, 120)
for mu, sig in [(8.352570533752441, 0.08843752971863869)]:
    plt.plot(x_values, gaussian(x_values, mu, sig))
